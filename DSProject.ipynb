# %% [markdown]
# ### Step-1 Install Pytorch

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# cd yolov5

# %%
# pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ###   Uses:-
#      torch -> To load the YOLO model and make Detection
#      matplotlib -> visualizing images
#      cv2 -> to access web cam and render feeds
#      numpy-> numerical calcullation

# %%
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)#load pretrained ultralytics model from torch hub
# Out:
# Using cache found in /Users/roshneekoirala/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-5-19 Python-3.11.7 torch-2.3.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# Images
imgs = ['https://i0.wp.com/calmatters.org/wp-content/uploads/2019/11/07222019_traffic_AW_sized_02.jpg?fit=1200%2C762&ssl=1']

# %% [markdown]
# # Detecting from Images

# %%
# Inference
results = model(imgs)
# Results
results.print()
results.show()
# Out:
# image 1/1: 762x1200 24 cars, 1 bus, 8 trucks
# Speed: 675.6ms pre-process, 90.7ms inference, 2.7ms NMS per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=1200x762>

# %%
 # %matplotlib inline
 # plt.imshow(np.squeeze(results.render()))
 # plt.show()

# %% [markdown]
# # Detecting From video

# %%
cap = cv2.VideoCapture('video.mp4')
while cap.isOpened():
    ret, frame = cap.read()
    # detection
    results = model(frame) 
    cv2.imshow('Object Detection', np.squeeze(results.render()))
    # to close the window
    if cv2.waitKey(10) & 0xFF == ord('q'):  
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Detecting From web cam

# %%
# access web camera
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    # detection
    results = model(frame) 
    cv2.imshow('Object Detection', np.squeeze(results.render()))
    # to close the window
    if cv2.waitKey(10) & 0xFF == ord('q'):  
        break
cap.release()
cv2.destroyAllWindows()
